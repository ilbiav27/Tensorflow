# %%
import os
import cv2
import numpy as np

import matplotlib.pyplot as plt
import post_processor_hs

# %%
#from base to post_pro
path_base = os.path.join('before_1')
path_post_pro = os.path.join('after')

# %%
def image_print(fig, i, img, name, num):
    #add column for print input images
    ax = fig.add_subplot(1, num, 1 + i, xticks=[], yticks=[])
    #add title that is probable name of type
    ax.set_title(name)
    plt.imshow(img)

# %%
#image num
images = os.listdir(".")
num = np.shape(images)[0]

for image in images:
    imgs, img_names = post_processor_hs.get_image(path_base, num, 256)

    #generate post processed images
    for i in range(num):
        cv2.imwrite(os.path.join(path_post_pro,img_names[i]),imgs[i])
"""        
#print them
fig = plt.figure(figsize=(round(60/num),round(60/num)))

for i in range(num):
    
    #cv -> matlab : BGR -> RGB
    b, g, r = cv2.split(imgs[i])
    img_ = cv2.merge([r,g,b])
    img_ = cv2.cvtColor(img[i], cv2.COLOR_BGR2RGB)
    
    image_print(fig, i,img_, 'SAMPLE',num)
"""
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a28e7caa072a> in <module>()
#       4
#       5 for image in images:
# ----> 6     imgs, img_names = post_processor_hs.get_image(path_base, num, 256)
#       7
#       8     #generate post processed images
#
# ~\jupyterNotebook\01_Wom_Classification\post_processor_hs.py in get_image(path, num, WH)
#      88         #read image
#      89         img_ = cv2.imread(path_img)
# ---> 90         major_color = get_major_color_at_borders(img_)
#      91         stretched = stretch_image(img_, major_color, WH)
#      92         img[i] = stretched
#
# ~\jupyterNotebook\01_Wom_Classification\post_processor_hs.py in get_major_color_at_borders(image)
#      53     for i in range(height):
#      54         for j in range(width):
# ...

# %%
#openCv -> matlab : bgr -> rgb
b, g, r = cv2.split(img)
img_ = cv2.merge([r,g,b])
image_print(fig, 0,img_, 'SAMPLE',1)
# Out:
# C:\Users\HSJung\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py:107: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
